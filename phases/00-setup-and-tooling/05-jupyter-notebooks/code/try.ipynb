# %%
print("hello world from jupyter notebook")

# %%
import numpy as np
x=np.random.randn(1000)
x.mean()
x.std()

# %%
# %timeit [x ** 2 for x in range(100000)]

# %%
# %timeit np.arange(100000) ** 2

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("My First Plot")
plt.show()

# %% [markdown]
# # It is my first time use jupyter in vscode
# - nihai
# - hello
# $\frac{a}{b}$

# %%
# Out:
# code  docs  outputs  quiz.json
